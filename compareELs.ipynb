# %%
import pandas as pd

# %%
df_amended_typed = pd.read_csv("data/processed/bpic15_amended_typed.csv")
df_our = pd.read_csv("output.csv")

# %%
COs = df2['CO_rule'].unique()
COs

CO_reps = [
    "null/6/M-T-W-T-F",
    "null/7/M-T-W-T-F",
    "null/8/M-T-W-T-F",
    "null/0-1-4-5/M-T-W-T-F",
    "null/2/M-T-W-T-F",
    "null/3/M-T-W-T-F",
    "null/7/Sat",
    "null/8/Sat",
    "null/0-1-4-5/Sat",
    "null/2/Sat",
    "null/3/Sat",
    "null/0-1-4-5/Sun"
]

df_lookup = pd.DataFrame({'CO_rule': COs, 'CO': CO_reps})

df_lookup[CO_rule]

df_our = pd.merge(df_our, df_lookup, how='left', on='CO_rule')
# Out:
#                                               CO_rule                      CO
# 0   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/6/M-T-W-T-F
# 1   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/7/M-T-W-T-F
# 2   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/8/M-T-W-T-F
# 3   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...  null/0-1-4-5/M-T-W-T-F
# 4   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/2/M-T-W-T-F
# 5   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/3/M-T-W-T-F
# 6   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...              null/7/Sat
# 7   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...              null/8/Sat
# 8   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/0-1-4-5/Sat
# 9   (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...              null/2/Sat
# 10  (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...              null/3/Sat
# 11  (T(NULL)) AND (`at:phase` ELEMENT OF {'01_HOOF...        null/0-1-4-5/Sun
